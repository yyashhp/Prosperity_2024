# %% [markdown]
# # Playing around with tutorial_data.csv

# %%
# Imports
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt # Won't be able to use this when submitting
import jsonpickle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt # Won't be able to use this when submitting
# ----> 5 import jsonpickle
#
# ModuleNotFoundError: No module named 'jsonpickle'

# %%
df = pd.read_csv("tutorial_data.csv") 
df
# Out:
#       day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0      -2          0  AMETHYSTS        10002             1       9996.0
# 1      -2          0  STARFRUIT         5002             1       4997.0
# 2      -2        100  AMETHYSTS         9996             2       9995.0
# 3      -2        100  STARFRUIT         4997            24          NaN
# 4      -2        200  STARFRUIT         4997             2       4996.0
# ...   ...        ...        ...          ...           ...          ...
# 3995   -2     199700  AMETHYSTS         9998             8       9996.0
# 3996   -2     199800  STARFRUIT         4949            21          NaN
# 3997   -2     199800  AMETHYSTS         9995            21          NaN
# 3998   -2     199900  STARFRUIT         4950            32          NaN
# 3999   -2     199900  AMETHYSTS         9996             2       9995.0
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
df["day"]
# Out:
# 0      -2
# 1      -2
# 2      -2
# 3      -2
# 4      -2
#        ..
# 3995   -2
# 3996   -2
# 3997   -2
# 3998   -2
# 3999   -2
# Name: day, Length: 4000, dtype: int64

# %%
df.isna().sum()
# Out:
# day                   0
# timestamp             0
# product               0
# bid_price_1           0
# bid_volume_1          0
# bid_price_2        1782
# bid_volume_2       1782
# bid_price_3        3590
# bid_volume_3       3590
# ask_price_1           0
# ask_volume_1          0
# ask_price_2        1853
# ask_volume_2       1853
# ask_price_3        3594
# ask_volume_3       3594
# mid_price             0
# profit_and_loss       0
# dtype: int64

# %%
df = pd.read_csv("tutorial_data_cl.csv") 
df
# Out:
#       day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0      -2          0  AMETHYSTS        10002             1         9996
# 1      -2          0  STARFRUIT         5002             1         4997
# 2      -2        100  AMETHYSTS         9996             2         9995
# 3      -2        100  STARFRUIT         4997            24            0
# 4      -2        200  STARFRUIT         4997             2         4996
# ...   ...        ...        ...          ...           ...          ...
# 3995   -2     199700  AMETHYSTS         9998             8         9996
# 3996   -2     199800  STARFRUIT         4949            21            0
# 3997   -2     199800  AMETHYSTS         9995            21            0
# 3998   -2     199900  STARFRUIT         4950            32            0
# 3999   -2     199900  AMETHYSTS         9996             2         9995
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
df['mid_price'].values.min()
# Out:
# 4948.5

# %%
amethyst_df = df[df['product'] == 'AMETHYSTS']
starfruit_df = df[df['product'] == 'STARFRUIT']

# %%
import statistics
from statistics import mean

# %%
def get_stats(prices):
    print(f" \t       Mean: {mean(prices)} \n  \
             Min: {min(prices)} \n  \
             Max: {max(prices)} \n  \
             median: {statistics.median(prices)} \n  \
             std: {statistics.stdev(prices)} \n  \
             length: {len((prices))} \n")

# %%
get_stats(amethyst_df['mid_price'])
# Out:
#  	       Mean: 10000.05375
#                Min: 9996.5
#                Max: 10003.5
#                median: 10000.0
#                std: 1.4813281554240525
#                length: 2000

# %%
get_stats(starfruit_df['mid_price'])
# Out:
#  	       Mean: 4980.30225
#                Min: 4948.5
#                Max: 5004.0
#                median: 4985.5
#                std: 14.271093230320313
#                length: 2000
